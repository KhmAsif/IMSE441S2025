# %% [markdown]
# <a href="https://colab.research.google.com/github/KhmAsif/IMSE441S2025/blob/main/Linear_Regression_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

#statistic
import scipy as scipy
from scipy import stats
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
#from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data

# %%
data = pd.read_csv('https://raw.githubusercontent.com/KhmAsif/IMSE441S2025/refs/heads/main/Oxygen%20purity.csv')
data.head(5)
# Out:
#    obs  hydrocarbon  purity
# 0    1         0.99   90.01
# 1    2         1.02   89.05
# 2    3         1.15   91.43
# 3    4         1.29   93.74
# 4    5         1.46   96.73

# %%
x = data[['hydrocarbon']]
y= data['purity']

# %% [markdown]
# # Normality Check

# %%
# %pip install pingouin
import pingouin as pg
# Out:
# Collecting pingouin
#   Downloading pingouin-0.5.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pingouin) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pingouin) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.11/dist-packages (from pingouin) (2.2.2)
# Collecting pandas-flavor (from pingouin)
#   Downloading pandas_flavor-0.7.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.11/dist-packages (from pingouin) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pingouin) (1.14.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from pingouin) (0.14.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from pingouin) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->pingouin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2->pingouin) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2->pingouin) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (3.2.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from pandas-flavor->pingouin) (2025.1.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->pingouin) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->pingouin) (1.17.0)
# Downloading pingouin-0.5.5-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 5.4 MB/s eta 0:00:00
# Downloading pandas_flavor-0.7.0-py3-none-any.whl (8.4 kB)
# Installing collected packages: pandas-flavor, pingouin
# Successfully installed pandas-flavor-0.7.0 pingouin-0.5.5

# %%
pg.qqplot(x)
plt.show()

# %%
pg.qqplot(y)
plt.show()

# %% [markdown]
# # **Regression: Method 1**

# %%
model_1 = lm.LinearRegression()
model_1.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', model_1.coef_)
print("y-intercept ", model_1.intercept_)
# Out:
# Coefficients:  [14.94747973]
# y-intercept  74.28331424039479

# %% [markdown]
# #**y= 74.283 + 14.947 *x**

# %%
y_pred = model_1.predict(x)
y_pred
# Out:
# array([89.08131918, 89.52974357, 91.47291593, 93.56556309, 96.10663465,
#        94.61188668, 87.28762161, 92.66871431, 97.45190783, 95.20978587,
#        92.07081512, 91.47291593, 88.93184438, 89.38026877, 90.87501674,
#        92.22028992, 93.1171387 , 94.01398749, 95.65821026, 88.48341999])

# %%
print("mean square error: ", mean_squared_error(y,y_pred))
# Out:
# mean square error:  1.0624908437610157

# %%
r_sq = model_1.score(x, y)
r_sq
# Out:
# 0.8774357051715553

# %% [markdown]
# # **Regression: Method 2**

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(x)
model_2 = sm.OLS(y, x).fit()
print(model_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 purity   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     128.9
# Date:                Thu, 24 Apr 2025   Prob (F-statistic):           1.23e-09
# Time:                        18:53:27   Log-Likelihood:                -28.985
# No. Observations:                  20   AIC:                             61.97
# Df Residuals:                      18   BIC:                             63.96
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          74.2833      1.593     46.617      0.000      70.936      77.631
# hydrocarbon    14.9475      1.317     11.352      0.000      12.181      17.714
# ==============================================================================
# Omnibus:                        0.532   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.766   Jarque-Bera (JB):                0.604
# Skew:                           0.157   Prob(JB):                        0.739
# Kurtosis:                       2.208   Cond. No.                         13.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # **Residual analysis: Model Validation**

# %%
residual = y - y_pred
residual
# Out:
# 0     0.928681
# 1    -0.479744
# 2    -0.042916
# 3     0.174437
# 4     0.623365
# 5    -0.161887
# 6     0.302378
# 7    -0.898714
# 8     1.968092
# 9    -1.559786
# 10    1.469185
# 11    1.047084
# 12    1.628156
# 13    0.159731
# 14   -1.025017
# 15   -1.830290
# 16    0.132861
# 17   -0.603987
# 18   -0.678210
# 19   -1.153420
# Name: purity, dtype: float64

# %%
res_squared = residual*residual
sse= res_squared.sum()
sse
# Out:
# np.float64(21.24981687522031)

# %%
pg.qqplot(residual)
plt.show()

# %% [markdown]
# # **Scatterplot: Model Validation**

# %%
plt.figure(figsize=(8,5))
plt.scatter(x['hydrocarbon'],y)
plt.plot(x['hydrocarbon'], y_pred, linewidth=2, color='red')
plt.xlabel('hydorcarbon')
plt.ylabel('purity')
plt.legend(['actual reading', 'fitted model'])
plt.title('Model Validation')
plt.show()

# %% [markdown]
# #**Residual plot: Model Validation**

# %%
fig = plt.figure(figsize=(10,8))
sm.graphics.plot_regress_exog(model_2, 'hydrocarbon',fig=fig)
plt.show()

# %% [markdown]
# # **Multiple Linear Regression**

# %% [markdown]
# # **Wine quality Data from textbook**

# %%
data2=pd.read_csv('https://raw.githubusercontent.com/KhmAsif/IMSE441S2025/refs/heads/main/Wine%20Quality%20Data.csv')
data2.head(10)
# Out:
#    Observation  Clarity  Aroma  Body  Flavor  Oakness  Quality
# 0            1      1.0    3.3   2.8     3.1      4.1      9.8
# 1            2      1.0    4.4   4.9     3.5      3.9     12.6
# 2            3      1.0    3.9   5.3     4.8      4.7     11.9
# 3            4      1.0    3.9   2.6     3.1      3.6     11.1
# 4            5      1.0    5.6   5.1     5.5      5.1     13.3
# 5            6      1.0    4.6   4.7     5.0      4.1     12.8
# 6            7      1.0    4.8   4.8     4.8      3.3     12.8
# 7            8      1.0    5.3   4.5     4.3      5.2     12.0
# 8            9      1.0    4.3   4.3     3.9      2.9     13.6
# 9           10      1.0    4.3   3.9     4.7      3.9     13.9

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Observation  38 non-null     int64
#  1   Clarity      38 non-null     float64
#  2   Aroma        38 non-null     float64
#  3   Body         38 non-null     float64
#  4   Flavor       38 non-null     float64
#  5   Oakness      38 non-null     float64
#  6   Quality      38 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 2.2 KB

# %%
x1 = data2[['Clarity',	'Aroma',	'Body',	'Flavor',	'Oakness']]
y1= data2['Quality']

# %%
import statsmodels.api as sm

# %%
x1 = sm.add_constant(x1)
model_3 = sm.OLS(y1, x1).fit()
print(model_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Quality   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     16.51
# Date:                Thu, 24 Apr 2025   Prob (F-statistic):           4.70e-08
# Time:                        19:04:12   Log-Likelihood:                -56.378
# No. Observations:                  38   AIC:                             124.8
# Df Residuals:                      32   BIC:                             134.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.9969      2.232      1.791      0.083      -0.549       8.543
# Clarity        2.3395      1.735      1.349      0.187      -1.194       5.873
# Aroma          0.4826      0.272      1.771      0.086      -0.072       1.038
# Body           0.2732      0.333      0.821      0.418      -0.404       0.951
# Flavor         1.1683      0.304      3.837      0.001       0.548       1.789
# Oakness       -0.6840      0.271     -2.522      0.017      -1.236      -0.132
# ==============================================================================
# Omnibus:                        1.181   Durbin-Watson:                   0.837
# Prob(Omnibus):                  0.554   Jarque-Bera (JB):                1.020
# Skew:                          -0.384   Prob(JB):                        0.601
# Kurtosis:                       2.770   Cond. No.                         134.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # We can see from Model 3 summary that clarity and Body p value is much higher. So we can say that clarity and Body amount don't have significant effect on the wine quality. Aroma does have a higer p value than alpha but still it is pretty close to 0.05. So, We can remodel the equation with only Aroma, FLavor and oakness as independent variables

# %%
x2= data2[['Aroma', 'Flavor',	'Oakness']]
y2= data2['Quality']

# %%
x2 = sm.add_constant(x2)
model_4 = sm.OLS(y2, x2).fit()
print(model_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Quality   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     26.92
# Date:                Thu, 24 Apr 2025   Prob (F-statistic):           4.20e-09
# Time:                        19:06:25   Log-Likelihood:                -57.489
# No. Observations:                  38   AIC:                             123.0
# Df Residuals:                      34   BIC:                             129.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.4672      1.333      4.852      0.000       3.759       9.176
# Aroma          0.5801      0.262      2.213      0.034       0.047       1.113
# Flavor         1.1997      0.275      4.364      0.000       0.641       1.758
# Oakness       -0.6023      0.264     -2.278      0.029      -1.140      -0.065
# ==============================================================================
# Omnibus:                        0.955   Durbin-Watson:                   0.837
# Prob(Omnibus):                  0.620   Jarque-Bera (JB):                0.964
# Skew:                          -0.338   Prob(JB):                        0.618
# Kurtosis:                       2.611   Cond. No.                         58.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x3= data2[['Aroma', 'Flavor']]
y3= data2['Quality']

# %%
x3 = sm.add_constant(x3)
model_5 = sm.OLS(y3, x3).fit()
print(model_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Quality   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.639
# Method:                 Least Squares   F-statistic:                     33.75
# Date:                Thu, 24 Apr 2025   Prob (F-statistic):           6.81e-09
# Time:                        19:07:20   Log-Likelihood:                -60.188
# No. Observations:                  38   AIC:                             126.4
# Df Residuals:                      35   BIC:                             131.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.3462      1.009      4.307      0.000       2.298       6.395
# Aroma          0.5180      0.276      1.877      0.069      -0.042       1.078
# Flavor         1.1702      0.291      4.027      0.000       0.580       1.760
# ==============================================================================
# Omnibus:                        0.321   Durbin-Watson:                   0.869
# Prob(Omnibus):                  0.852   Jarque-Bera (JB):                0.499
# Skew:                           0.076   Prob(JB):                        0.779
# Kurtosis:                       2.460   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # **Scatterplot: Model Validation**

# %% [markdown]
# # **Equation: Quality= 6.4672+ 0.58 * Aroma+ 1.1997 * Flavor -0.6023* Oakness**

# %%
y2_pred = model_4.predict(x2)

# %%
residual_2=y2-y2_pred

# %%
pg.qqplot(residual_2)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
sm.graphics.plot_regress_exog(model_4, 'Aroma',fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
sm.graphics.plot_regress_exog(model_4, 'Flavor',fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
sm.graphics.plot_regress_exog(model_4, 'Oakness',fig=fig)
plt.show()
