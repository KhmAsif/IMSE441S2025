# %% [markdown]
# <a href="https://colab.research.google.com/github/KhmAsif/IMSE441S2025/blob/main/Data_Cleaning%26Preparation_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Data upload

# %%
data=pd.read_csv('https://raw.githubusercontent.com/KhmAsif/IMSE441S2025/refs/heads/main/diabetic_data.csv')

# %%
data.head(5)
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %% [markdown]
# # Data type check

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %% [markdown]
# # Data type modification

# %%
#data['Year']=data['Year'].astype(object)
data['admission_type_id']=data['admission_type_id'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     100 non-null    int64
#  1   encounter_id              100 non-null    int64
#  2   patient_nbr               100 non-null    int64
#  3   gender                    100 non-null    object
#  4   age                       100 non-null    object
#  5   admission_type_id         100 non-null    int64
#  6   discharge_disposition_id  100 non-null    int64
#  7   admission_source_id       100 non-null    int64
#  8   time_in_hospital          100 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 7.2+ KB

# %%
data['Year']=data['Year'].astype(float)

# %% [markdown]
# # **Data selection**

# %%
data=data.drop(['race','weight'], axis=1)

# %%
data.head()
# Out:
#    encounter_id  patient_nbr  gender      age  admission_type_id  \
# 0       2278392      8222157  Female   [0-10)                  6
# 1        149190     55629189  Female  [10-20)                  1
# 2         64410     86047875  Female  [20-30)                  1
# 3        500364     82442376    Male  [30-40)                  1
# 4         16680     42519267    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1          ?
# 1                         1                    7                 3          ?
# 2                         1                    7                 2          ?
# 3                         1                    7                 2          ?
# 4                         1                    7                 1          ?
#
#           medical_specialty  ...  citoglipton  insulin  glyburide-metformin  \
# ...

# %%
data=data.iloc[0:100,0:10]

# %%
data
# Out:
#     encounter_id  patient_nbr  gender      age  admission_type_id  \
# 0        2278392      8222157  Female   [0-10)                  6
# 1         149190     55629189  Female  [10-20)                  1
# 2          64410     86047875  Female  [20-30)                  1
# 3         500364     82442376    Male  [30-40)                  1
# 4          16680     42519267    Male  [40-50)                  1
# ..           ...          ...     ...      ...                ...
# 95       1195056     79549353    Male  [70-80)                  2
# 96       1195548    106343838  Female  [70-80)                  1
# 97       1212006     84981816    Male  [70-80)                  1
# 98       1257282     84488562  Female  [50-60)                  1
# 99       1260216     92117574    Male  [30-40)                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                         25                    1                 1
# ...

# %%
data=data.drop(['payer_code','medical_specialty'], axis=1)

# %%
data
# Out:
#     encounter_id  patient_nbr  gender      age  admission_type_id  \
# 0        2278392      8222157  Female   [0-10)                  6
# 1         149190     55629189  Female  [10-20)                  1
# 2          64410     86047875  Female  [20-30)                  1
# 3         500364     82442376    Male  [30-40)                  1
# 4          16680     42519267    Male  [40-50)                  1
# ..           ...          ...     ...      ...                ...
# 95       1195056     79549353    Male  [70-80)                  2
# 96       1195548    106343838  Female  [70-80)                  1
# 97       1212006     84981816    Male  [70-80)                  1
# 98       1257282     84488562  Female  [50-60)                  1
# 99       1260216     92117574    Male  [30-40)                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital
# 0                         25                    1                 1
# ...

# %%
data=data[data['season']>2010]

# %%
data.head(20)

# %%
data.head(20)

# %%
data.head(20)

# %% [markdown]
# # Removing duplicates and null values

# %%
data.isnull()
# Out:
#     encounter_id  patient_nbr  gender    age  admission_type_id  \
# 0          False        False   False  False              False
# 1          False        False   False  False              False
# 2          False        False   False  False              False
# 3          False        False   False  False              False
# 4          False        False   False  False              False
# ..           ...          ...     ...    ...                ...
# 95         False        False   False  False              False
# 96         False        False   False  False              False
# 97         False        False   False  False              False
# 98         False        False   False  False              False
# 99         False        False   False  False              False
#
#     discharge_disposition_id  admission_source_id  time_in_hospital
# 0                      False                False             False
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#     encounter_id  patient_nbr  gender      age  admission_type_id  \
# 0        2278392      8222157  Female   [0-10)                  6
# 1         149190     55629189  Female  [10-20)                  1
# 2          64410     86047875  Female  [20-30)                  1
# 3         500364     82442376    Male  [30-40)                  1
# 4          16680     42519267    Male  [40-50)                  1
# ..           ...          ...     ...      ...                ...
# 95       1195056     79549353    Male  [70-80)                  2
# 96       1195548    106343838  Female  [70-80)                  1
# 97       1212006     84981816    Male  [70-80)                  1
# 98       1257282     84488562  Female  [50-60)                  1
# 99       1260216     92117574    Male  [30-40)                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital
# 0                         25                    1                 1
# ...

# %%
data.drop_duplicates()
# Out:
#     encounter_id  patient_nbr  gender      age  admission_type_id  \
# 0        2278392      8222157  Female   [0-10)                  6
# 1         149190     55629189  Female  [10-20)                  1
# 2          64410     86047875  Female  [20-30)                  1
# 3         500364     82442376    Male  [30-40)                  1
# 4          16680     42519267    Male  [40-50)                  1
# ..           ...          ...     ...      ...                ...
# 95       1195056     79549353    Male  [70-80)                  2
# 96       1195548    106343838  Female  [70-80)                  1
# 97       1212006     84981816    Male  [70-80)                  1
# 98       1257282     84488562  Female  [50-60)                  1
# 99       1260216     92117574    Male  [30-40)                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital
# 0                         25                    1                 1
# ...

# %%
data = data.reset_index()

# %%
data
# Out:
#     index  encounter_id  patient_nbr  gender      age  admission_type_id  \
# 0       0       2278392      8222157  Female   [0-10)                  6
# 1       1        149190     55629189  Female  [10-20)                  1
# 2       2         64410     86047875  Female  [20-30)                  1
# 3       3        500364     82442376    Male  [30-40)                  1
# 4       4         16680     42519267    Male  [40-50)                  1
# ..    ...           ...          ...     ...      ...                ...
# 95     95       1195056     79549353    Male  [70-80)                  2
# 96     96       1195548    106343838  Female  [70-80)                  1
# 97     97       1212006     84981816    Male  [70-80)                  1
# 98     98       1257282     84488562  Female  [50-60)                  1
# 99     99       1260216     92117574    Male  [30-40)                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital
# ...
